# %% [markdown]
# <a href="https://colab.research.google.com/github/nimraa9090/ANN-DL-PRJ/blob/main/ANN_%26_DL_PRJ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget -O anerbc_dataset.zip https://data.mendeley.com/public-api/zip/hms3sjzt7f/download/1
# Out:
# --2026-06-13 10:16:28--  https://data.mendeley.com/public-api/zip/hms3sjzt7f/download/1
# Resolving data.mendeley.com (data.mendeley.com)... 162.159.130.86, 162.159.133.86
# Connecting to data.mendeley.com (data.mendeley.com)|162.159.130.86|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !ls
# Out:
# anerbc_dataset.zip  sample_data

# %%
# !unzip anerbc_dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: AneRBC dataset a benchmark dataset for computer-aided anemia diagnosis using RBC images. httpsdoi.org10.1093databasebaae120/AneRBC_dataset/AneRBC-II/Healthy_individuals/RGB_segmented/0084_05_h.png
#   inflating: AneRBC dataset a benchmark dataset for computer-aided anemia diagnosis using RBC images. httpsdoi.org10.1093databasebaae120/AneRBC_dataset/AneRBC-II/Healthy_individuals/RGB_segmented/0084_06_h.png
#   inflating: AneRBC dataset a benchmark dataset for computer-aided anemia diagnosis using RBC images. httpsdoi.org10.1093databasebaae120/AneRBC_dataset/AneRBC-II/Healthy_individuals/RGB_segmented/0084_07_h.png
#   inflating: AneRBC dataset a benchmark dataset for computer-aided anemia diagnosis using RBC images. httpsdoi.org10.1093databasebaae120/AneRBC_dataset/AneRBC-II/Healthy_individuals/RGB_segmented/0084_08_h.png
# ...
